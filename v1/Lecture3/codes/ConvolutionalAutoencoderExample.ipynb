# %% [markdown]
# # Convolutional Autoencoder Example
# modified from https://blog.keras.io/building-autoencoders-in-keras.html

# %% [markdown]
# ## Prepare Data Set

# %%
import tensorflow as tf
import numpy as np
import scipy.io
mnist = scipy.io.loadmat('mnist.mat')
x_train = mnist['train'].swapaxes(0,2).swapaxes(1,2)
x_test = mnist['test'].swapaxes(0,2).swapaxes(1,2)
#from tensorflow.keras.datasets import mnist
#(x_train, _),(x_test, _) = mnist.load_data()
# Out:
# /home/wangj/anaconda3/envs/DLiES/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 88 from C header, got 96 from PyObject
#   return f(*args, **kwds)

# %% [markdown]
# ## Check Data

# %%
import matplotlib.pyplot as plt
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train = np.reshape(x_train, (60000, 28, 28,1))
x_test = np.reshape(x_test, (10000, 28, 28,1))

print('x_train shape: {}  x_test shape: {}'.format(np.shape(x_train),np.shape(x_test)))
for i in range(16):
    plt.subplot(4, 4, 1 + i, xticks=[], yticks=[])
    img_id = np.random.randint(np.shape(x_train)[0])
    im = x_train[img_id,::].reshape([28,28])
    plt.imshow(im)
    plt.gray()
# Out:
# x_train shape: (60000, 28, 28, 1)  x_test shape: (10000, 28, 28, 1)

# %% [markdown]
# ## Build Model

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D

autoencoder = tf.keras.Sequential()
#Encoder
autoencoder.add(Conv2D(32,(3,3),activation='relu',padding='same',input_shape=x_train.shape[1:]))
autoencoder.add(MaxPooling2D(pool_size=(2, 2)))
autoencoder.add(Conv2D(32,(3,3),activation='relu',padding='same'))

#Compressed representation
autoencoder.add(MaxPooling2D(pool_size=(2, 2)))

#Decoder
autoencoder.add(Conv2D(32,(3,3),activation='relu',padding='same'))
autoencoder.add(UpSampling2D((2, 2)))
autoencoder.add(Conv2D(32,(3,3),activation='relu',padding='same'))
autoencoder.add(UpSampling2D((2, 2)))
autoencoder.add(Conv2D(1,(3,3),activation='sigmoid',padding='same'))

autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 32)          9248
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 32)        9248
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 1)         289
# =================================================================
# Total params: 28,353
# Trainable params: 28,353
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train Model

# %%
autoencoder.compile(optimizer='adadelta', loss='mse')

autoencoder.fit(x_train, x_train,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 43s 719us/step - loss: 6.8904 - val_loss: 2.1242
# Epoch 2/100
# 60000/60000 [==============================] - 2s 34us/step - loss: 2.2163 - val_loss: 1.3828
# Epoch 3/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 1.6349 - val_loss: 1.1028
# Epoch 4/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 1.3571 - val_loss: 0.9557
# Epoch 5/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 1.1885 - val_loss: 0.8967
# Epoch 6/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 1.0697 - val_loss: 0.8010
# Epoch 7/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.9824 - val_loss: 0.7371
# Epoch 8/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.9196 - val_loss: 0.7029
# Epoch 9/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.8726 - val_loss: 0.6628
# Epoch 10/100
# 60000/60000 [==============================] - 2s 42us/step - loss: 0.8298 - val_loss: 0.6450
# Epoch 11/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.7925 - val_loss: 0.6531
# Epoch 12/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.7646 - val_loss: 0.5944
# Epoch 13/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.7372 - val_loss: 0.5719
# Epoch 14/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.7118 - val_loss: 0.5580
# Epoch 15/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.6905 - val_loss: 0.5469
# Epoch 16/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.6775 - val_loss: 0.5306
# Epoch 17/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.6561 - val_loss: 0.5208
# Epoch 18/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.6455 - val_loss: 0.5112
# Epoch 19/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.6265 - val_loss: 0.4954
# Epoch 20/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.6108 - val_loss: 0.4958
# Epoch 21/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.6016 - val_loss: 0.4833
# Epoch 22/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.5923 - val_loss: 0.4795
# Epoch 23/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.5780 - val_loss: 0.4743
# Epoch 24/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.5709 - val_loss: 0.4700
# Epoch 25/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.5543 - val_loss: 0.4485
# Epoch 26/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.5516 - val_loss: 0.4430
# Epoch 27/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.5407 - val_loss: 0.4393
# Epoch 28/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.5347 - val_loss: 0.4352
# Epoch 29/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.5302 - val_loss: 0.4296
# Epoch 30/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.5247 - val_loss: 0.4261
# Epoch 31/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.5176 - val_loss: 0.4286
# Epoch 32/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.5139 - val_loss: 0.4135
# Epoch 33/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.4979 - val_loss: 0.4069
# Epoch 34/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.4927 - val_loss: 0.4016
# Epoch 35/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.4909 - val_loss: 0.4011
# Epoch 36/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.4906 - val_loss: 0.4003
# Epoch 37/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.4832 - val_loss: 0.4013
# Epoch 38/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.4810 - val_loss: 0.3970
# Epoch 39/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.4790 - val_loss: 0.3912
# Epoch 40/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.4704 - val_loss: 0.3805
# Epoch 41/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.4674 - val_loss: 0.3843
# Epoch 42/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.4632 - val_loss: 0.3776
# Epoch 43/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.4612 - val_loss: 0.3713
# Epoch 44/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.4574 - val_loss: 0.3680
# Epoch 45/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.4513 - val_loss: 0.3941
# Epoch 46/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.4481 - val_loss: 0.3661
# Epoch 47/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.4480 - val_loss: 0.3690
# Epoch 48/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.4448 - val_loss: 0.3636
# Epoch 49/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.4434 - val_loss: 0.3616
# Epoch 50/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.4387 - val_loss: 0.3568
# Epoch 51/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.4336 - val_loss: 0.3541
# Epoch 52/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.4313 - val_loss: 0.3520
# Epoch 53/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.4304 - val_loss: 0.3491
# Epoch 54/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.4269 - val_loss: 0.3585
# Epoch 55/100
# 60000/60000 [==============================] - 2s 42us/step - loss: 0.4236 - val_loss: 0.3515
# Epoch 56/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.4228 - val_loss: 0.3436
# Epoch 57/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.4203 - val_loss: 0.3456
# Epoch 58/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.4183 - val_loss: 0.3422
# Epoch 59/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.4152 - val_loss: 0.3398
# Epoch 60/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.4153 - val_loss: 0.3454
# Epoch 61/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.4138 - val_loss: 0.3367
# Epoch 62/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.4125 - val_loss: 0.3363
# Epoch 63/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.4087 - val_loss: 0.3346
# Epoch 64/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.4078 - val_loss: 0.3338
# Epoch 65/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.4074 - val_loss: 0.3326
# Epoch 66/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.4045 - val_loss: 0.3302
# Epoch 67/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.4027 - val_loss: 0.3304
# Epoch 68/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.4008 - val_loss: 0.3309
# Epoch 69/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.4008 - val_loss: 0.3258
# Epoch 70/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.3994 - val_loss: 0.3301
# Epoch 71/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.3989 - val_loss: 0.3236
# Epoch 72/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.3940 - val_loss: 0.3198
# Epoch 73/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.3940 - val_loss: 0.3277
# Epoch 74/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.3938 - val_loss: 0.3198
# Epoch 75/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.3904 - val_loss: 0.3229
# Epoch 76/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.3899 - val_loss: 0.3243
# Epoch 77/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.3897 - val_loss: 0.3225
# Epoch 78/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.3883 - val_loss: 0.3169
# Epoch 79/100
# 60000/60000 [==============================] - 2s 42us/step - loss: 0.3850 - val_loss: 0.3145
# Epoch 80/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.3869 - val_loss: 0.3177
# Epoch 81/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.3821 - val_loss: 0.3137
# Epoch 82/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.3815 - val_loss: 0.3116
# Epoch 83/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.3808 - val_loss: 0.3121
# Epoch 84/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.3823 - val_loss: 0.3163
# Epoch 85/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.3836 - val_loss: 0.3162
# Epoch 86/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.3835 - val_loss: 0.3160
# Epoch 87/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.3772 - val_loss: 0.3157
# Epoch 88/100
# 60000/60000 [==============================] - 2s 42us/step - loss: 0.3764 - val_loss: 0.3106
# Epoch 89/100
# 60000/60000 [==============================] - 2s 42us/step - loss: 0.3754 - val_loss: 0.3130
# Epoch 90/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.3764 - val_loss: 0.3119
# Epoch 91/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.3763 - val_loss: 0.3136
# Epoch 92/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.3737 - val_loss: 0.3075
# Epoch 93/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.3736 - val_loss: 0.3093
# Epoch 94/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.3725 - val_loss: 0.3072
# Epoch 95/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.3715 - val_loss: 0.3055
# Epoch 96/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.3674 - val_loss: 0.3066
# Epoch 97/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.3670 - val_loss: 0.3023
# Epoch 98/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.3681 - val_loss: 0.3016
# Epoch 99/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.3676 - val_loss: 0.3004
# Epoch 100/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.3692 - val_loss: 0.3088

# %% [markdown]
# ## Evaluate Model

# %%
x_recon = autoencoder.predict(x_test)
for i in range(16):
    plt.subplot(4, 8, 1 + i*2, xticks=[], yticks=[])
    img_id = np.random.randint(np.shape(x_test)[0])
    im = x_test[img_id,::].reshape([28,28])
    plt.imshow(im)
    plt.gray()
    plt.title('Ori')
    plt.subplot(4, 8, 2 + i*2, xticks=[], yticks=[])
    
    im = x_recon[img_id,::].reshape([28,28])
    plt.imshow(im)
    plt.gray()
    plt.title('AE')

# %% [markdown]
# # Denosing with Autoencoder

# %% [markdown]
# ## Add noise to data

# %%
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape) 
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %% [markdown]
# ## Check Data

# %%
for i in range(16):
    plt.subplot(4, 4, 1 + i, xticks=[], yticks=[])
    img_id = np.random.randint(np.shape(x_train)[0])
    im = x_train_noisy[img_id,::].reshape([28,28])
    plt.imshow(im)
    plt.gray()

# %% [markdown]
# ## Create a New Model for Denosing

# %%
tf.reset_default_graph()
tf.keras.backend.clear_session()

autoencoder = tf.keras.Sequential()
#Encoder
autoencoder.add(Conv2D(32,(3,3),activation='relu',padding='same',input_shape=x_train.shape[1:]))
autoencoder.add(MaxPooling2D(pool_size=(2, 2)))
autoencoder.add(Conv2D(16,(3,3),activation='relu',padding='same'))
#Compressed representation
autoencoder.add(MaxPooling2D(pool_size=(2, 2)))

#Decoder
autoencoder.add(Conv2D(16,(3,3),activation='relu',padding='same'))
autoencoder.add(UpSampling2D((2, 2)))
autoencoder.add(Conv2D(32,(3,3),activation='relu',padding='same'))
autoencoder.add(UpSampling2D((2, 2)))
autoencoder.add(Conv2D(1,(3,3),activation='sigmoid',padding='same'))

autoencoder.summary()

autoencoder.compile(optimizer='adadelta', loss='mse')

autoencoder.fit(x_train_noisy, x_train,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 16)        4624
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 16)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 16)          2320
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 32)        4640
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 1)         289
# =================================================================
# Total params: 12,193
# Trainable params: 12,193
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 13.9838 - val_loss: 4.4444
# Epoch 2/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 5.8698 - val_loss: 2.9936
# Epoch 3/100
# 60000/60000 [==============================] - 2s 34us/step - loss: 4.8015 - val_loss: 2.3548
# Epoch 4/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 4.3287 - val_loss: 2.2158
# Epoch 5/100
# 60000/60000 [==============================] - 2s 34us/step - loss: 4.0489 - val_loss: 2.0442
# Epoch 6/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 3.8595 - val_loss: 1.7923
# Epoch 7/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 3.7146 - val_loss: 1.6924
# Epoch 8/100
# 60000/60000 [==============================] - 2s 34us/step - loss: 3.6288 - val_loss: 1.6531
# Epoch 9/100
# 60000/60000 [==============================] - 2s 34us/step - loss: 3.5365 - val_loss: 1.5617
# Epoch 10/100
# 60000/60000 [==============================] - 2s 34us/step - loss: 3.4730 - val_loss: 1.6393
# Epoch 11/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 3.4120 - val_loss: 1.5401
# Epoch 12/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 3.3699 - val_loss: 1.5057
# Epoch 13/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 3.3353 - val_loss: 1.4927
# Epoch 14/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 3.2893 - val_loss: 1.4493
# Epoch 15/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 3.2517 - val_loss: 1.3967
# Epoch 16/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 3.2312 - val_loss: 1.3617
# Epoch 17/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 3.2107 - val_loss: 1.3896
# Epoch 18/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 3.1789 - val_loss: 1.3494
# Epoch 19/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 3.1669 - val_loss: 1.3155
# Epoch 20/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 3.1414 - val_loss: 1.3189
# Epoch 21/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 3.1306 - val_loss: 1.3223
# Epoch 22/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 3.1022 - val_loss: 1.2839
# Epoch 23/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 3.0989 - val_loss: 1.2663
# Epoch 24/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 3.0754 - val_loss: 1.2608
# Epoch 25/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 3.0668 - val_loss: 1.3066
# Epoch 26/100
# 60000/60000 [==============================] - 3s 46us/step - loss: 3.0605 - val_loss: 1.2477
# Epoch 27/100
# 60000/60000 [==============================] - 3s 45us/step - loss: 3.0212 - val_loss: 1.2509
# Epoch 28/100
# 60000/60000 [==============================] - 3s 45us/step - loss: 3.0204 - val_loss: 1.2336
# Epoch 29/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 2.9967 - val_loss: 1.2536
# Epoch 30/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 3.0052 - val_loss: 1.2610
# Epoch 31/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 2.9984 - val_loss: 1.2375
# Epoch 32/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 2.9984 - val_loss: 1.2347
# Epoch 33/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 2.9738 - val_loss: 1.2294
# Epoch 34/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 2.9714 - val_loss: 1.2190
# Epoch 35/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 2.9676 - val_loss: 1.2291
# Epoch 36/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 2.9589 - val_loss: 1.2179
# Epoch 37/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 2.9561 - val_loss: 1.2249
# Epoch 38/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 2.9550 - val_loss: 1.2630
# Epoch 39/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 2.9470 - val_loss: 1.2233
# Epoch 40/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 2.9348 - val_loss: 1.2378
# Epoch 41/100
# 60000/60000 [==============================] - 2s 42us/step - loss: 2.9326 - val_loss: 1.2148
# Epoch 42/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 2.9209 - val_loss: 1.1946
# Epoch 43/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 2.9170 - val_loss: 1.2284
# Epoch 44/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 2.9191 - val_loss: 1.2051
# Epoch 45/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 2.9163 - val_loss: 1.2071
# Epoch 46/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 2.9064 - val_loss: 1.2007
# Epoch 47/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 2.8993 - val_loss: 1.2226
# Epoch 48/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 2.8996 - val_loss: 1.2086
# Epoch 49/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 2.9136 - val_loss: 1.2018
# Epoch 50/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 2.8991 - val_loss: 1.1808
# Epoch 51/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 2.8919 - val_loss: 1.2072
# Epoch 52/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 2.8962 - val_loss: 1.2055
# Epoch 53/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 2.8939 - val_loss: 1.1947
# Epoch 54/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 2.8845 - val_loss: 1.1921
# Epoch 55/100
# 60000/60000 [==============================] - 3s 45us/step - loss: 2.9008 - val_loss: 1.2126
# Epoch 56/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 2.8982 - val_loss: 1.2219
# Epoch 57/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 2.8899 - val_loss: 1.1864
# Epoch 58/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 2.8793 - val_loss: 1.1902
# Epoch 59/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 2.8907 - val_loss: 1.1937
# Epoch 60/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 2.9001 - val_loss: 1.1992
# Epoch 61/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 2.8858 - val_loss: 1.1954
# Epoch 62/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 2.8830 - val_loss: 1.1841
# Epoch 63/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 2.8820 - val_loss: 1.1884
# Epoch 64/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 2.8658 - val_loss: 1.1707
# Epoch 65/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 2.8719 - val_loss: 1.1853
# Epoch 66/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 2.8729 - val_loss: 1.1967
# Epoch 67/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 2.8849 - val_loss: 1.1911
# Epoch 68/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 2.8767 - val_loss: 1.1734
# Epoch 69/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 2.8746 - val_loss: 1.1973
# Epoch 70/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 2.8572 - val_loss: 1.1814
# Epoch 71/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 2.8761 - val_loss: 1.2011
# Epoch 72/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 2.8757 - val_loss: 1.1841
# Epoch 73/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 2.8717 - val_loss: 1.1767
# Epoch 74/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 2.8690 - val_loss: 1.1796
# Epoch 75/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 2.8738 - val_loss: 1.1758
# Epoch 76/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 2.8589 - val_loss: 1.2000
# Epoch 77/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 2.8560 - val_loss: 1.1807
# Epoch 78/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 2.8561 - val_loss: 1.1949
# Epoch 79/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 2.8602 - val_loss: 1.2010
# Epoch 80/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 2.8486 - val_loss: 1.1711
# Epoch 81/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 2.8467 - val_loss: 1.1740
# Epoch 82/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 2.8515 - val_loss: 1.1959
# Epoch 83/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 2.8448 - val_loss: 1.1705
# Epoch 84/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 2.8375 - val_loss: 1.1657
# Epoch 85/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 2.8509 - val_loss: 1.1767
# Epoch 86/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 2.8391 - val_loss: 1.1711
# Epoch 87/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 2.8287 - val_loss: 1.1607
# Epoch 88/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 2.8534 - val_loss: 1.1557
# Epoch 89/100
# 60000/60000 [==============================] - 3s 48us/step - loss: 2.8461 - val_loss: 1.1923
# Epoch 90/100
# 60000/60000 [==============================] - 3s 46us/step - loss: 2.8523 - val_loss: 1.1883
# Epoch 91/100
# 60000/60000 [==============================] - 3s 47us/step - loss: 2.8483 - val_loss: 1.1807
# Epoch 92/100
# 60000/60000 [==============================] - 3s 46us/step - loss: 2.8403 - val_loss: 1.1765
# Epoch 93/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 2.8413 - val_loss: 1.1699
# Epoch 94/100
# 60000/60000 [==============================] - 3s 45us/step - loss: 2.8334 - val_loss: 1.1552
# Epoch 95/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 2.8505 - val_loss: 1.1611
# Epoch 96/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 2.8382 - val_loss: 1.1587
# Epoch 97/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 2.8390 - val_loss: 1.1738
# Epoch 98/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 2.8590 - val_loss: 1.1901
# Epoch 99/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 2.8385 - val_loss: 1.1682
# Epoch 100/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 2.8336 - val_loss: 1.1819

# %% [markdown]
# ## Evaluate Model

# %%
x_denoise = autoencoder.predict(x_test_noisy)
for i in range(16):
    plt.subplot(4, 8, 1 + i*2, xticks=[], yticks=[])
    img_id = np.random.randint(np.shape(x_test_noisy)[0])
    im = x_test_noisy[img_id,::].reshape([28,28])
    plt.imshow(im)
    plt.gray()
    plt.title('Ori')
    plt.subplot(4, 8, 2 + i*2, xticks=[], yticks=[])
    
    im = x_denoise[img_id,::].reshape([28,28])
    plt.imshow(im)
    plt.gray()
    plt.title('AE')

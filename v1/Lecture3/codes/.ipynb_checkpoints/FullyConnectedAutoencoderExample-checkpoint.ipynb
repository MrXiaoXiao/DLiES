# %% [markdown]
# # Fully Connected Autoencoder Example
# modified from https://blog.keras.io/building-autoencoders-in-keras.html

# %% [markdown]
# ## Prepare Data Set

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import numpy as np
(x_train, _),(x_test, _) = mnist.load_data()

# %% [markdown]
# ## Check Data

# %%
import matplotlib.pyplot as plt
print('x_train shape: {}  x_test shape: {}'.format(np.shape(x_train),np.shape(x_test)))
for i in range(16):
    plt.subplot(4, 4, 1 + i, xticks=[], yticks=[])
    img_id = np.random.randint(np.shape(x_train)[0])
    im = x_train[img_id,::]
    plt.imshow(im)
    plt.gray()
# Out:
# x_train shape: (60000, 28, 28)  x_test shape: (10000, 28, 28)

# %% [markdown]
# ## Preprocessing Data

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %% [markdown]
# ## Build Model

# %%
from tensorflow.keras.layers import Dense
autoencoder = tf.keras.Sequential()
#Decoder
autoencoder.add(Dense(128,activation='relu',input_shape=(784,)))
autoencoder.add(Dense(64,activation='relu'))

#Compressed representation
autoencoder.add(Dense(32,activation='relu'))

#Encoder
autoencoder.add(Dense(64,activation='relu'))
autoencoder.add(Dense(128,activation='relu'))
autoencoder.add(Dense(784,activation='sigmoid'))

autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_5 (Dense)              (None, 784)               101136
# =================================================================
# Total params: 222,384
# Trainable params: 222,384
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train Model

# %%
autoencoder.compile(optimizer='adadelta', loss='mse')

autoencoder.fit(x_train, x_train,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.1129 - val_loss: 0.0693
# Epoch 2/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0683 - val_loss: 0.0679
# Epoch 3/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0670 - val_loss: 0.0667
# Epoch 4/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0658 - val_loss: 0.0653
# Epoch 5/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.0635 - val_loss: 0.0615
# Epoch 6/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0594 - val_loss: 0.0576
# Epoch 7/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0565 - val_loss: 0.0552
# Epoch 8/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0545 - val_loss: 0.0531
# Epoch 9/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0526 - val_loss: 0.0513
# Epoch 10/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0507 - val_loss: 0.0492
# Epoch 11/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0487 - val_loss: 0.0477
# Epoch 12/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.0470 - val_loss: 0.0455
# Epoch 13/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.0447 - val_loss: 0.0434
# Epoch 14/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0429 - val_loss: 0.0418
# Epoch 15/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.0415 - val_loss: 0.0404
# Epoch 16/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0403 - val_loss: 0.0394
# Epoch 17/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0394 - val_loss: 0.0385
# Epoch 18/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0387 - val_loss: 0.0379
# Epoch 19/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0377 - val_loss: 0.0369
# Epoch 20/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.0369 - val_loss: 0.0360
# Epoch 21/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0359 - val_loss: 0.0351
# Epoch 22/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.0351 - val_loss: 0.0341
# Epoch 23/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0345 - val_loss: 0.0339
# Epoch 24/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0337 - val_loss: 0.0330
# Epoch 25/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0330 - val_loss: 0.0324
# Epoch 26/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0323 - val_loss: 0.0314
# Epoch 27/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0316 - val_loss: 0.0308
# Epoch 28/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0311 - val_loss: 0.0306
# Epoch 29/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0304 - val_loss: 0.0298
# Epoch 30/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0299 - val_loss: 0.0292
# Epoch 31/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.0293 - val_loss: 0.0288
# Epoch 32/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0288 - val_loss: 0.0282
# Epoch 33/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0284 - val_loss: 0.0278
# Epoch 34/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0280 - val_loss: 0.0275
# Epoch 35/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.0276 - val_loss: 0.0267
# Epoch 36/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.0273 - val_loss: 0.0266
# Epoch 37/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0270 - val_loss: 0.0264
# Epoch 38/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0266 - val_loss: 0.0261
# Epoch 39/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0263 - val_loss: 0.0263
# Epoch 40/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0260 - val_loss: 0.0259
# Epoch 41/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.0258 - val_loss: 0.0253
# Epoch 42/100
# 60000/60000 [==============================] - 3s 51us/step - loss: 0.0255 - val_loss: 0.0250
# Epoch 43/100
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0252 - val_loss: 0.0247
# Epoch 44/100
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0250 - val_loss: 0.0245
# Epoch 45/100
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0248 - val_loss: 0.0246
# Epoch 46/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0245 - val_loss: 0.0237
# Epoch 47/100
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0242 - val_loss: 0.0235
# Epoch 48/100
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0239 - val_loss: 0.0233
# Epoch 49/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0236 - val_loss: 0.0230
# Epoch 50/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.0234 - val_loss: 0.0228
# Epoch 51/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0232 - val_loss: 0.0224
# Epoch 52/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.0229 - val_loss: 0.0226
# Epoch 53/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.0227 - val_loss: 0.0220
# Epoch 54/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0225 - val_loss: 0.0219
# Epoch 55/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0224 - val_loss: 0.0216
# Epoch 56/100
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.0222 - val_loss: 0.0216
# Epoch 57/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0220 - val_loss: 0.0214
# Epoch 58/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0219 - val_loss: 0.0214
# Epoch 59/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0217 - val_loss: 0.0213
# Epoch 60/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0216 - val_loss: 0.0211
# Epoch 61/100
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.0215 - val_loss: 0.0207
# Epoch 62/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0214 - val_loss: 0.0209
# Epoch 63/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.0212 - val_loss: 0.0207
# Epoch 64/100
# 60000/60000 [==============================] - 3s 53us/step - loss: 0.0211 - val_loss: 0.0206
# Epoch 65/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0210 - val_loss: 0.0205
# Epoch 66/100
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0208 - val_loss: 0.0203
# Epoch 67/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0207 - val_loss: 0.0203
# Epoch 68/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.0206 - val_loss: 0.0199
# Epoch 69/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.0204 - val_loss: 0.0198
# Epoch 70/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.0203 - val_loss: 0.0198
# Epoch 71/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.0202 - val_loss: 0.0196
# Epoch 72/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0200 - val_loss: 0.0197
# Epoch 73/100
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0198 - val_loss: 0.0193
# Epoch 74/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0197 - val_loss: 0.0196
# Epoch 75/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0196 - val_loss: 0.0193
# Epoch 76/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0194 - val_loss: 0.0190
# Epoch 77/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0193 - val_loss: 0.0187
# Epoch 78/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0192 - val_loss: 0.0187
# Epoch 79/100
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0190 - val_loss: 0.0188
# Epoch 80/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0190 - val_loss: 0.0188
# Epoch 81/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0188 - val_loss: 0.0184
# Epoch 82/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.0187 - val_loss: 0.0187
# Epoch 83/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.0186 - val_loss: 0.0183
# Epoch 84/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0185 - val_loss: 0.0179
# Epoch 85/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.0184 - val_loss: 0.0179
# Epoch 86/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0182 - val_loss: 0.0176
# Epoch 87/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0182 - val_loss: 0.0175
# Epoch 88/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.0181 - val_loss: 0.0179
# Epoch 89/100
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0180 - val_loss: 0.0177
# Epoch 90/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0179 - val_loss: 0.0175
# Epoch 91/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0178 - val_loss: 0.0175
# Epoch 92/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0177 - val_loss: 0.0177
# Epoch 93/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0177 - val_loss: 0.0173
# Epoch 94/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0176 - val_loss: 0.0174
# Epoch 95/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0175 - val_loss: 0.0172
# Epoch 96/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0174 - val_loss: 0.0170
# Epoch 97/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0174 - val_loss: 0.0167
# Epoch 98/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0173 - val_loss: 0.0168
# Epoch 99/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0172 - val_loss: 0.0168
# Epoch 100/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0171 - val_loss: 0.0171

# %% [markdown]
# ## Evaluate Model

# %%
x_recon = autoencoder.predict(x_test)
for i in range(16):
    plt.subplot(4, 8, 1 + i*2, xticks=[], yticks=[])
    img_id = np.random.randint(np.shape(x_test)[0])
    im = x_test[img_id,::].reshape([28,28])
    plt.imshow(im)
    plt.gray()
    plt.title('Ori')
    plt.subplot(4, 8, 2 + i*2, xticks=[], yticks=[])
    
    im = x_recon[img_id,::].reshape([28,28])
    plt.imshow(im)
    plt.gray()
    plt.title('AE')

# %% [markdown]
# # Denosing with Autoencoder

# %% [markdown]
# ## Add noise to data

# %%
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape) 
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %% [markdown]
# ## Check Data

# %%
for i in range(16):
    plt.subplot(4, 4, 1 + i, xticks=[], yticks=[])
    img_id = np.random.randint(np.shape(x_train)[0])
    im = x_train_noisy[img_id,::].reshape([28,28])
    plt.imshow(im)
    plt.gray()

# %% [markdown]
# ## Create a New Model for Denosing

# %%
tf.reset_default_graph()
tf.keras.backend.clear_session()
autoencoder = tf.keras.Sequential()
#Decoder
autoencoder.add(Dense(128,activation='relu',input_shape=(784,)))
autoencoder.add(Dense(64,activation='relu'))

#Compressed representation
autoencoder.add(Dense(32,activation='relu'))

#Encoder
autoencoder.add(Dense(64,activation='relu'))
autoencoder.add(Dense(128,activation='relu'))
autoencoder.add(Dense(784,activation='sigmoid'))

#Train
autoencoder.compile(optimizer='adadelta', loss='mse')

autoencoder.fit(x_train, x_train,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.1222 - val_loss: 0.0698
# Epoch 2/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.0687 - val_loss: 0.0681
# Epoch 3/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0671 - val_loss: 0.0665
# Epoch 4/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0650 - val_loss: 0.0636
# Epoch 5/100
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0626 - val_loss: 0.0620
# Epoch 6/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0612 - val_loss: 0.0605
# Epoch 7/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0592 - val_loss: 0.0577
# Epoch 8/100
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.0566 - val_loss: 0.0555
# Epoch 9/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0545 - val_loss: 0.0528
# Epoch 10/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0516 - val_loss: 0.0497
# Epoch 11/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0486 - val_loss: 0.0471
# Epoch 12/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0465 - val_loss: 0.0453
# Epoch 13/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0451 - val_loss: 0.0439
# Epoch 14/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.0439 - val_loss: 0.0427
# Epoch 15/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0428 - val_loss: 0.0419
# Epoch 16/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.0417 - val_loss: 0.0405
# Epoch 17/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0407 - val_loss: 0.0400
# Epoch 18/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.0397 - val_loss: 0.0387
# Epoch 19/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0387 - val_loss: 0.0377
# Epoch 20/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.0378 - val_loss: 0.0368
# Epoch 21/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0371 - val_loss: 0.0364
# Epoch 22/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0365 - val_loss: 0.0358
# Epoch 23/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.0359 - val_loss: 0.0354
# Epoch 24/100
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0354 - val_loss: 0.0345
# Epoch 25/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.0348 - val_loss: 0.0342
# Epoch 26/100
# 60000/60000 [==============================] - 3s 51us/step - loss: 0.0342 - val_loss: 0.0333
# Epoch 27/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0335 - val_loss: 0.0327
# Epoch 28/100
# 60000/60000 [==============================] - 3s 52us/step - loss: 0.0328 - val_loss: 0.0321
# Epoch 29/100
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0322 - val_loss: 0.0317
# Epoch 30/100
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0316 - val_loss: 0.0310
# Epoch 31/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.0310 - val_loss: 0.0302
# Epoch 32/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.0304 - val_loss: 0.0300
# Epoch 33/100
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.0299 - val_loss: 0.0295
# Epoch 34/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.0294 - val_loss: 0.0285
# Epoch 35/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0289 - val_loss: 0.0292
# Epoch 36/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.0286 - val_loss: 0.0282
# Epoch 37/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.0282 - val_loss: 0.0276
# Epoch 38/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0279 - val_loss: 0.0272
# Epoch 39/100
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0275 - val_loss: 0.0271
# Epoch 40/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0272 - val_loss: 0.0264
# Epoch 41/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0269 - val_loss: 0.0262
# Epoch 42/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0266 - val_loss: 0.0260
# Epoch 43/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0264 - val_loss: 0.0259
# Epoch 44/100
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.0261 - val_loss: 0.0261
# Epoch 45/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0260 - val_loss: 0.0255
# Epoch 46/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0257 - val_loss: 0.0252
# Epoch 47/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0255 - val_loss: 0.0251
# Epoch 48/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0253 - val_loss: 0.0249
# Epoch 49/100
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.0252 - val_loss: 0.0245
# Epoch 50/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0249 - val_loss: 0.0243
# Epoch 51/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0247 - val_loss: 0.0241
# Epoch 52/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0245 - val_loss: 0.0239
# Epoch 53/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0243 - val_loss: 0.0237
# Epoch 54/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.0241 - val_loss: 0.0236
# Epoch 55/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0239 - val_loss: 0.0233
# Epoch 56/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0237 - val_loss: 0.0232
# Epoch 57/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0236 - val_loss: 0.0232
# Epoch 58/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0233 - val_loss: 0.0229
# Epoch 59/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0232 - val_loss: 0.0227
# Epoch 60/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0230 - val_loss: 0.0228
# Epoch 61/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.0229 - val_loss: 0.0224
# Epoch 62/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0227 - val_loss: 0.0221
# Epoch 63/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.0225 - val_loss: 0.0225
# Epoch 64/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0224 - val_loss: 0.0219
# Epoch 65/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0222 - val_loss: 0.0217
# Epoch 66/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0220 - val_loss: 0.0215
# Epoch 67/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.0218 - val_loss: 0.0216
# Epoch 68/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.0217 - val_loss: 0.0211
# Epoch 69/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.0215 - val_loss: 0.0212
# Epoch 70/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0213 - val_loss: 0.0211
# Epoch 71/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0211 - val_loss: 0.0207
# Epoch 72/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0209 - val_loss: 0.0206
# Epoch 73/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0207 - val_loss: 0.0204
# Epoch 74/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.0206 - val_loss: 0.0200
# Epoch 75/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.0204 - val_loss: 0.0203
# Epoch 76/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0202 - val_loss: 0.0199
# Epoch 77/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0200 - val_loss: 0.0195
# Epoch 78/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0198 - val_loss: 0.0198
# Epoch 79/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0196 - val_loss: 0.0194
# Epoch 80/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0195 - val_loss: 0.0189
# Epoch 81/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.0193 - val_loss: 0.0187
# Epoch 82/100
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0192 - val_loss: 0.0185
# Epoch 83/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0190 - val_loss: 0.0187
# Epoch 84/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0189 - val_loss: 0.0186
# Epoch 85/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0188 - val_loss: 0.0183
# Epoch 86/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0187 - val_loss: 0.0183
# Epoch 87/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0186 - val_loss: 0.0182
# Epoch 88/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0185 - val_loss: 0.0182
# Epoch 89/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0184 - val_loss: 0.0179
# Epoch 90/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0183 - val_loss: 0.0177
# Epoch 91/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0183 - val_loss: 0.0179
# Epoch 92/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.0181 - val_loss: 0.0180
# Epoch 93/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0181 - val_loss: 0.0176
# Epoch 94/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0180 - val_loss: 0.0178
# Epoch 95/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.0179 - val_loss: 0.0174
# Epoch 96/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0178 - val_loss: 0.0174
# Epoch 97/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0177 - val_loss: 0.0173
# Epoch 98/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0176 - val_loss: 0.0173
# Epoch 99/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0176 - val_loss: 0.0171
# Epoch 100/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0174 - val_loss: 0.0169

# %% [markdown]
# ## Evaluate Model

# %%
x_denoise = autoencoder.predict(x_test_noisy)
for i in range(16):
    plt.subplot(4, 8, 1 + i*2, xticks=[], yticks=[])
    img_id = np.random.randint(np.shape(x_test_noisy)[0])
    im = x_test_noisy[img_id,::].reshape([28,28])
    plt.imshow(im)
    plt.gray()
    plt.title('Ori')
    plt.subplot(4, 8, 2 + i*2, xticks=[], yticks=[])
    
    im = x_denoise[img_id,::].reshape([28,28])
    plt.imshow(im)
    plt.gray()
    plt.title('AE')
